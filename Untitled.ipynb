# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import requests
import pandas as pd
endpoint_url = 'https://www.googleapis.com/youtube/v3/search'

search = 'data science'

#https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=20&q=YOURKEYWORD&type=video&key=YOURAPIKEY

API_Token = 'AIzaSyCNAG1Wau_psGi_UywtjzVOxN7rucEAAIU'

# PERFORM THE QUERY
id_list = []
date_list = []
name_list = []                                         # create empty lists to hold data
desc_list = []
img_list = []
url_list = []

max_results = 50
                                                            # max offset is 2000 including limit           # while loop to run with conditional variables
query = f'{endpoint_url}'
query += f'?part=snippet'
query += f'&maxResults={max_results}'
query += f'&q={search}'                       # format search query with assigned variables
query += f'&type=video'
query += f'&key={API_Token}'

response = requests.get(query)                                          # get request)  
json_response = response.json()  # as a json file
print(json_response)
for i in range(len(json_response['items'])):                      # loop through json
        id_list.append(json_response['items'][i]['id']['videoId'])               # pull out info from json
        name_list.append(json_response['items'][i]['snippet']['title'])           # into empty lists
        desc_list.append(json_response['items'][i]['snippet']['description'])
        date_list.append(json_response['items'][i]['snippet']['publishTime'])
        img_list.append(json_response['items'][i]['snippet']['thumbnails']['default']['url'])
        url_list.append('https://www.youtube.com/watch?v='+json_response['items'][i]['id']['videoId'])

#Fetching only 50 results due to the quota
        
pages = int(json_response['pageInfo']['totalResults']/json_response['pageInfo']['resultsPerPage'])        
pageToken = json_response['nextPageToken']

for i in range(10):
    
    query2 = f'{endpoint_url}'
    query2 += f'?part=snippet'
    query2 += f'&maxResults={max_results}'
    query2 += f'&pageToken={pageToken}'
    query2 += f'&q={search}'                       # format search query with assigned variables
    query2 += f'&type=video'
    query2 += f'&key={API_Token}'

    response = requests.get(query2)                                          # get request)  
    json_response2 = response.json()                                  # as a json file
    pageToken = json_response2['nextPageToken']
    
    for i in range(len(json_response2['items'])):                      # loop through json
        id_list.append(json_response2['items'][i]['id']['videoId'])               # pull out info from json
        name_list.append(json_response2['items'][i]['snippet']['title'])           # into empty lists
        desc_list.append(json_response2['items'][i]['snippet']['description'])
        date_list.append(json_response2['items'][i]['snippet']['publishTime'])
        img_list.append(json_response2['items'][i]['snippet']['thumbnails']['default']['url'])
        url_list.append('https://www.youtube.com/watch?v='+json_response['items'][i]['id']['videoId'])
        
        

#Build Dataframe with all videos
videos = pd.DataFrame()

videos['id'] = id_list
videos['name'] = name_list
videos['description'] = desc_list
videos['images'] = img_list
videos['url'] = url_list
videos['title_and_description'] = videos['name'] + ' ' + videos['description']
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'X-tvoHvG8gG99FU92fI5Wu00mGI', 'nextPageToken': 'CDIQAA', 'regionCode': 'DE', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'BAPOFYztgIZvdjUDD0Es_OHPbyk', 'id': {'kind': 'youtube#video', 'videoId': 'xC-c7E5PK0Y'}, 'snippet': {'publishedAt': '2018-06-23T01:51:50Z', 'channelId': 'UCV0qA-eDDICsRR9rPcnG7tw', 'title': 'What REALLY is Data Science? Told by a Data Scientist', 'description': 'Learn how to code with Python 3 for Data Science and Software Engineering. High-quality video courses: http://python.jomaclass.com/ ▻ Resume Template and ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xC-c7E5PK0Y/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/xC-c7E5PK0Y/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/xC-c7E5PK0Y/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Joma Tec
# ...

# %%
data = videos

# %%
from modules import preprocessing

# %%
preprocessing.preprocessed_data(data, 'title_and_description').to_csv('data/data_youtube_preprocessed.csv')

# %%
data
# Out:
#               id                                               name  \
# 0    xC-c7E5PK0Y  What REALLY is Data Science? Told by a Data Sc...
# 1    X3paOmcrTjQ  Data Science In 5 Minutes | Data Science For B...
# 2    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 3    ua-CiDNNj30  Learn Data Science Tutorial - Full Course for ...
# 4    Ck0ozfJV9-g              A Day In The Life Of A Data Scientist
# ..           ...                                                ...
# 545  XD4f-3f7T54  Online Data Science Programs (B.Sc. Data Scien...
# 546  iG6CoReKViM  15 Days Workshop on Python Application in the ...
# 547  4q_7lgoVfN4                 Data Science with Hadoop and Spark
# 548  gF10CrR1DnE  الوظائف والأدوار الرئيسية في علم البيانات | Da...
# 549  qchuCSeqzJ0  Data Science For Beginners l What is Data Scie...
#
#                                            description  \
# 0    Learn how to code with Python 3 for Data Scien...
# ...

# %%
data = pd.read_csv('data/medium_data.csv')

# %%
data
# Out:
#         id                                                url  \
# 0        1  https://towardsdatascience.com/a-beginners-gui...
# 1        2  https://towardsdatascience.com/hands-on-graph-...
# 2        3  https://towardsdatascience.com/how-to-use-ggpl...
# 3        4  https://towardsdatascience.com/databricks-how-...
# 4        5  https://towardsdatascience.com/a-step-by-step-...
# ...    ...                                                ...
# 6503  6504  https://medium.com/better-marketing/we-vs-i-ho...
# 6504  6505  https://medium.com/better-marketing/how-donald...
# 6505  6506  https://medium.com/better-marketing/content-an...
# 6506  6507  https://medium.com/better-marketing/5-question...
# 6507  6508  https://medium.com/better-marketing/how-to-wri...
#
#                                                   title  \
# 0     A Beginner’s Guide to Word Embedding with Gens...
# 1     Hands-on Graph Neural Networks with PyTorch & ...
# ...

# %%
from modules import preprocessing

# %%
preprocessing.preprocessed_data(data, 'title').to_csv('data/data_medium_preprocessed.csv')

# %%
data = pd.read_csv('data/data_medium_preprocessed.csv')

# %%
data
# Out:
#       Unnamed: 0    id                                                url  \
# 0              0     1  https://towardsdatascience.com/a-beginners-gui...
# 1              1     2  https://towardsdatascience.com/hands-on-graph-...
# 2              2     3  https://towardsdatascience.com/how-to-use-ggpl...
# 3              3     4  https://towardsdatascience.com/databricks-how-...
# 4              4     5  https://towardsdatascience.com/a-step-by-step-...
# ...          ...   ...                                                ...
# 6503        6503  6504  https://medium.com/better-marketing/we-vs-i-ho...
# 6504        6504  6505  https://medium.com/better-marketing/how-donald...
# 6505        6505  6506  https://medium.com/better-marketing/content-an...
# 6506        6506  6507  https://medium.com/better-marketing/5-question...
# 6507        6507  6508  https://medium.com/better-marketing/how-to-wri...
#
#                                                   title  \
# ...
